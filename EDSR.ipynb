# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !unzip /content/drive/MyDrive/Celeba.zip
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: Celeba/train_LR/X4/img_2266x4.png
#   inflating: Celeba/train_LR/X4/img_363x4.png
#   inflating: Celeba/train_LR/X4/img_1678x4.png
#   inflating: Celeba/train_LR/X4/img_182x4.png
#   inflating: Celeba/train_LR/X4/img_553x4.png
#   inflating: Celeba/train_LR/X4/img_984x4.png
#   inflating: Celeba/train_LR/X4/img_516x4.png
#   inflating: Celeba/train_LR/X4/img_1720x4.png
#   inflating: Celeba/train_LR/X4/img_1765x4.png
#   inflating: Celeba/train_LR/X4/img_2087x4.png
#   inflating: Celeba/train_LR/X4/img_2456x4.png
#   inflating: Celeba/train_LR/X4/img_2881x4.png
#   inflating: Celeba/train_LR/X4/img_2413x4.png
#   inflating: Celeba/train_LR/X4/img_1349x4.png
#   inflating: Celeba/train_LR/X4/img_1798x4.png
#   inflating: Celeba/train_LR/X4/img_617x4.png
#   inflating: Celeba/train_LR/X4/img_979x4.png
#   inflating: Celeba/train_LR/X4/img_1421x4.png
#   inflating: Celeba/train_LR/X4/img_2712x4.png
# ...

# %%
# !git clone https://github.com/thstkdgus35/EDSR-PyTorch
# %cd EDSR-PyTorch/src
# Out:
# Cloning into 'EDSR-PyTorch'...
# remote: Enumerating objects: 806, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 806 (delta 0), reused 1 (delta 0), pack-reused 797
# Receiving objects: 100% (806/806), 63.10 MiB | 30.65 MiB/s, done.
# Resolving deltas: 100% (511/511), done.
# /content/EDSR-PyTorch/src

# %%
# !python /content/EDSR-PyTorch/src/main.py --model EDSR --scale 2 --save edsr_baseline_x2 --save_models --save_results --dir_data /content/ --data_train Celeba --data_test Celeba --pre_train /content/drive/MyDrive/model_7.pt
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from /content/drive/MyDrive/model_7.pt
# Preparing loss function:
# 1.000 * L1
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:429: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 2.8876]	15.4+17.8s
# [3200/16000]	[L1: 2.8223]	13.6+17.9s
# [4800/16000]	[L1: 2.8092]	13.5+17.8s
# ...

# %%
# !python main.py --dir_data /content/ --n_GPUs 1 --rgb_range 255 --chunk_size 144 --n_hashes 4 --save_models --lr 1e-5 --decay 20-40-60-80 --epochs 100 --patch_size 128 --chop --save '/content/drive/MyDrive/' --save_results  --n_resblocks 32 --n_feats 256 --res_scale 0.1 --batch_size 16 --model NLSN --scale 2 --patch_size 96 --save EDSR --data_train Celeba --data_test Celeba
# Out:
# python3: can't open file 'main.py': [Errno 2] No such file or directory

# %%
# !python /content/EDSR-PyTorch/src/main.py --model EDSR --lr 1e-5 --scale 2 --save edsr_baseline_x2 --save_models --save_results --dir_data /content/ --data_train Celeba --data_test Celeba --pre_train /content/drive/MyDrive/model_20.pt
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from /content/drive/MyDrive/model_20.pt
# Preparing loss function:
# 1.000 * L1
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:429: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-5
# [1600/16000]	[L1: 2.5663]	15.3+17.8s
# [3200/16000]	[L1: 2.5775]	13.6+17.9s
# [4800/16000]	[L1: 2.5860]	13.5+17.8s
# ...

# %%
# !python /content/EDSR-PyTorch/src/main.py --model EDSR --scale 2 --data_range '801-900' --save edsr_baseline_x2 --save_models --save_results --dir_data /content/ --data_train Celeba --data_test Celeba --pre_train /content/drive/MyDrive/edsr_best.pt --test_only
# Out:
# Making a binary: /content/Celeba/bin/train_HR/img_2053.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2054.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2055.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2058.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2059.pt
# Making a binary: /content/Celeba/bin/train_HR/img_206.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2060.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2061.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2062.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2063.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2064.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2065.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2066.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2067.pt
# Making a binary: /content/Celeba/bin/train_HR/img_2069.pt
# Making a binary: /content/Celeba/bin/train_HR/img_207.pt
# ...

# %%
# !python /content/EDSR-PyTorch/src/main.py --model EDSR --scale 2 --save edsr_baseline_x2 --save_models --data_range '0-100' --save_results --dir_data /content/drive/MyDrive/ --data_train Celeba --data_test Celeba --pre_train /content/drive/MyDrive/edsr_best.pt --test_only
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Load the model from /content/drive/MyDrive/edsr_best.pt
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 1/1 [00:12<00:00, 12.13s/it]
# [Celeba x2]	PSNR: 49.952 (Best: 49.952 @epoch 1)
# Forward: 12.44s
#
# Saving...
# Total: 14.96s

# %%
# !python /content/EDSR-PyTorch/src/main.py --model EDSR --scale 2 --save edsr_baseline_x2 --save_models --data_range '0-10/10-1000' --save_results --dir_data /content/ --data_train Celeba --data_test Celeba --pre_train /content/drive/MyDrive/edsr_best.pt --test_only
# Out:
# Making a binary: /content/Celeba/bin/test_HR/img_1061.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1062.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1063.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1064.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1065.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1066.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1067.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1070.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1071.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1072.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1073.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1074.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1075.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1076.pt
# Making a binary: /content/Celeba/bin/test_HR/img_1077.pt
# Making a binary: /content/Celeba/bin/test_HR/img_108.pt
# ...
