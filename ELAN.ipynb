# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd /content/
# !unzip /content/drive/MyDrive/Celeba.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Celeba/train_LR/X4/img_2266x4.png
#   inflating: Celeba/train_LR/X4/img_363x4.png
#   inflating: Celeba/train_LR/X4/img_1678x4.png
#   inflating: Celeba/train_LR/X4/img_182x4.png
#   inflating: Celeba/train_LR/X4/img_553x4.png
#   inflating: Celeba/train_LR/X4/img_984x4.png
#   inflating: Celeba/train_LR/X4/img_516x4.png
#   inflating: Celeba/train_LR/X4/img_1720x4.png
#   inflating: Celeba/train_LR/X4/img_1765x4.png
#   inflating: Celeba/train_LR/X4/img_2087x4.png
#   inflating: Celeba/train_LR/X4/img_2456x4.png
#   inflating: Celeba/train_LR/X4/img_2881x4.png
#   inflating: Celeba/train_LR/X4/img_2413x4.png
#   inflating: Celeba/train_LR/X4/img_1349x4.png
#   inflating: Celeba/train_LR/X4/img_1798x4.png
#   inflating: Celeba/train_LR/X4/img_617x4.png
#   inflating: Celeba/train_LR/X4/img_979x4.png
#   inflating: Celeba/train_LR/X4/img_1421x4.png
#   inflating: Celeba/train_LR/X4/img_2712x4.png
# ...

# %%
# !git clone https://github.com/xindongzhang/ELAN.git
# %cd ELAN
# Out:
# Cloning into 'ELAN'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 43 (delta 17), reused 22 (delta 5), pack-reused 0
# Unpacking objects: 100% (43/43), done.
# /content/drive/MyDrive/ELAN/ELAN/ELAN

# %%
# !pip install pytorch_msssim
# !pip install einops
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 4.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 23.4 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/ELAN
# !python train.py --config ./configs/elan_light_x4.yml
# Out:
# /content/drive/MyDrive/ELAN
# use cuda & cudnn for acceleration!
# the gpu id is: [0]
# Traceback (most recent call last):
#   File "train.py", line 47, in <module>
#     train_dataloader, valid_dataloaders = create_datasets(args)
#   File "/content/drive/MyDrive/ELAN/datas/utils.py", line 8, in create_datasets
#     celeba = Celeba(
#   File "/content/drive/MyDrive/ELAN/datas/celeba.py", line 75, in __init__
#     img_paths_hr = os.listdir(self.HR_folder)
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Celeba/train_HR'

# %%
# !python train.py --config ./configs/elan_light_x4.yml
# Out:
# use cuda & cudnn for acceleration!
# the gpu id is: [0]
# ...

# %%
# !nvidia-smi
# Out:
# Mon Jan  9 17:57:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    28W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip /content/drive/MyDrive/CelebaHQ.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: CelebaHQ/train_LR/X2/058616x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/060348x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/058147x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/124584x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/099042x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/033896x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/007044x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/123654x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/137492x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/021644x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/152052x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/152703x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/020422x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/051093x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/114439x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/178969x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/136312x2.jpeg
#   inflating: CelebaHQ/train_LR/X2/008026x2.jpeg
# ...

# %%
# %cd /content/drive/MyDrive/ELAN_HQ/
# !python train.py --config ./configs/elan_light_x4.yml
# Out:
# /content/drive/MyDrive/ELAN_HQ
# use cuda & cudnn for acceleration!
# the gpu id is: [0]
# ...

# %%
# %cd /content/
# !unzip /content/drive/MyDrive/benchmark.zip
# Out:
# /content
# Archive:  /content/drive/MyDrive/benchmark.zip
#    creating: benchmark/
#   inflating: __MACOSX/._benchmark
#    creating: benchmark/Set5/
#   inflating: __MACOSX/benchmark/._Set5
#    creating: benchmark/Set14/
#   inflating: __MACOSX/benchmark/._Set14
#    creating: benchmark/B100/
#   inflating: __MACOSX/benchmark/._B100
#    creating: benchmark/Urban100/
#   inflating: __MACOSX/benchmark/._Urban100
#    creating: benchmark/Set5/LR_bicubic/
#   inflating: __MACOSX/benchmark/Set5/._LR_bicubic
#    creating: benchmark/Set5/HR/
#   inflating: __MACOSX/benchmark/Set5/._HR
#    creating: benchmark/Set14/LR_bicubic/
#   inflating: __MACOSX/benchmark/Set14/._LR_bicubic
#    creating: benchmark/Set14/HR/
#   inflating: __MACOSX/benchmark/Set14/._HR
#    creating: benchmark/B100/LR_bicubic/
#   inflating: __MACOSX/benchmark/B100/._LR_bicubic
#    creating: benchmark/B100/HR/
#   inflating: __MACOSX/benchmark/B100/._HR
#    creating: benchmark/Urban100/LR_bicubic/
# ...

# %%
# %cd /content/drive/MyDrive/ELAN/
# !python train.py --config ./configs/elan_light_x4.yml
# Out:
# /content/drive/MyDrive/ELAN
# use cuda & cudnn for acceleration!
# the gpu id is: [0]
# ...

# %%
# %cd /content/drive/MyDrive/ELAN/
# !python train.py --config ./configs/elan_light_x4.yml
# Out:
# /content/drive/MyDrive/ELAN
# use cuda & cudnn for acceleration!
# the gpu id is: [0]
# ...
