# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# !unzip /content/drive/MyDrive/Celeba.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Celeba/train_LR/X4/img_2266x4.png
#   inflating: Celeba/train_LR/X4/img_363x4.png
#   inflating: Celeba/train_LR/X4/img_1678x4.png
#   inflating: Celeba/train_LR/X4/img_182x4.png
#   inflating: Celeba/train_LR/X4/img_553x4.png
#   inflating: Celeba/train_LR/X4/img_984x4.png
#   inflating: Celeba/train_LR/X4/img_516x4.png
#   inflating: Celeba/train_LR/X4/img_1720x4.png
#   inflating: Celeba/train_LR/X4/img_1765x4.png
#   inflating: Celeba/train_LR/X4/img_2087x4.png
#   inflating: Celeba/train_LR/X4/img_2456x4.png
#   inflating: Celeba/train_LR/X4/img_2881x4.png
#   inflating: Celeba/train_LR/X4/img_2413x4.png
#   inflating: Celeba/train_LR/X4/img_1349x4.png
#   inflating: Celeba/train_LR/X4/img_1798x4.png
#   inflating: Celeba/train_LR/X4/img_617x4.png
#   inflating: Celeba/train_LR/X4/img_979x4.png
#   inflating: Celeba/train_LR/X4/img_1421x4.png
#   inflating: Celeba/train_LR/X4/img_2712x4.png
# ...

# %%
# !tar -xvf /content/drive/MyDrive/DIV2K.tar -C /content/

# %%
# !git clone https://github.com/HarukiYqM/Non-Local-Sparse-Attention
# Out:
# Cloning into 'Non-Local-Sparse-Attention'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 156 (delta 32), reused 108 (delta 10), pack-reused 0
# Receiving objects: 100% (156/156), 386.82 KiB | 22.75 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd /content/Non-Local-Sparse-Attention/src/
# Out:
# /content/Non-Local-Sparse-Attention/src

# %%
# !python main.py --dir_data /content/ --n_GPUs 1 --rgb_range 255 --chunk_size 144 --n_hashes 4 --save_models --lr 1e-4 --decay 20-40-60-80 --epochs 100 --patch_size 128 --chop --save '/content/drive/MyDrive/' --save_results  --n_resblocks 32 --n_feats 256 --res_scale 0.1 --batch_size 16 --model NLSN --scale 2 --patch_size 96 --save NLSN_x2 --data_train Celeba --data_test Celeba --pre_train /content/drive/MyDrive/model_16.pt
# Out:
# Making a binary: /content/Celeba/bin/train_HR/img_0.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1.pt
# Making a binary: /content/Celeba/bin/train_HR/img_10.pt
# Making a binary: /content/Celeba/bin/train_HR/img_100.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1000.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1001.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1002.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1003.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1004.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1005.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1008.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1009.pt
# Making a binary: /content/Celeba/bin/train_HR/img_101.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1010.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1011.pt
# Making a binary: /content/Celeba/bin/train_HR/img_1014.pt
# ...

# %%
# !python main.py --dir_data /content/ --n_GPUs 1 --rgb_range 255 --chunk_size 144 --n_hashes 4 --save_models --lr 1e-5 --decay 20-40-60-80 --epochs 100 --patch_size 128 --chop --save '/content/drive/MyDrive/' --save_results  --n_resblocks 32 --n_feats 256 --res_scale 0.1 --batch_size 16 --model NLSN --scale 2 --patch_size 96 --save NLSN_x2 --data_train Celeba --data_test Celeba --pre_train /content/drive/MyDrive/model_20.pt
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 18 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Loading model from /content/drive/MyDrive/model_20.pt
# Total params: 41.80M
# Preparing loss function:
# 1.000 * L1
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:429: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-5
# [1600/16000]	[L1: 2.5555]	179.4+1.5s
# [3200/16000]	[L1: 2.5150]	177.5+0.9s
# ...

# %%
# !python main.py --dir_data /content/ --n_GPUs 1 --rgb_range 255 --chunk_size 144 --n_hashes 4 --save_models --lr 1e-6 --decay 20-40-60-80 --epochs 100 --patch_size 128 --chop --save '/content/drive/MyDrive/' --save_results  --n_resblocks 32 --n_feats 256 --res_scale 0.1 --batch_size 16 --model NLSN --scale 2 --patch_size 96 --save NLSN_x2 --data_train Celeba --data_test Celeba --pre_train /content/drive/MyDrive/model_25.pt
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 18 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Loading model from /content/drive/MyDrive/model_25.pt
# Total params: 41.80M
# Preparing loss function:
# 1.000 * L1
# /usr/local/lib/python3.8/dist-packages/torch/optim/lr_scheduler.py:429: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# [Epoch 1]	Learning rate: 1.00e-6
# [1600/16000]	[L1: 2.5216]	171.6+1.5s
# [3200/16000]	[L1: 2.4862]	177.2+0.9s
# ...

# %%
# !python main.py --dir_data /content/drive/MyDrive/dataset/ --n_GPUs 1 --rgb_range 1 --chunk_size 144 --n_hashes 4 --save_models --lr 1e-4 --decay 200-400-600-800 --epochs 2 --chop --save_results --n_resblocks 32 --n_feats 256 --res_scale 0.1 --batch_size 16 --model NLSN --scale 2 --patch_size 96 --save NLSN_x2 --data_train Custom --pre_train /content/drive/MyDrive/NLSN_pretrained/model_x2.pt

# %%
# No self-ensemble: NLSN
# Example X2 SR
# !python main.py --dir_data /content/Non-Local-Sparse-Attention/src/ --data_range '801-900' --model NLSN  --rgb_range 255 --chunk_size 144 --data_test Celeba --n_hashes 4 --chop --save_results --scale 2 --n_feats 256 --n_resblocks 32 --res_scale 0.1  --pre_train /content/drive/MyDrive/nlsn_best.pt --test_only
# Out:
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2044.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2045.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2046.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2047.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2048.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2049.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_205.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2050.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2051.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2052.pt
# Making a binary: /content/Non-Local-Sparse-Attention/src/Celeba/bin/train_HR/img_2053.pt
# ...

# %%
# !python main.py --dir_data /content/drive/MyDrive/ --model NLSN --data_range '0-10' --rgb_range 255 --chunk_size 144 --data_test Celeba --n_hashes 4 --chop --save_results --scale 2 --n_feats 256 --n_resblocks 32 --res_scale 0.1  --pre_train /content/drive/MyDrive/nlsn_best.pt --test_only
# Out:
# Making a binary: /content/drive/MyDrive/Celeba/bin/train_HR/000121.pt
# Making a binary: /content/drive/MyDrive/Celeba/bin/train_LR/X2/000121x2.pt
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 18 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Loading model from /content/drive/MyDrive/nlsn_best.pt
# Total params: 41.80M
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 1/1 [00:23<00:00, 23.16s/it]
# [Celeba x2]	PSNR: 49.925 (Best: 49.925 @epoch 1)
# Forward: 23.52s
#
# Saving...
# Total: 25.95s

# %%
gt = cv2.imread('/content/drive/MyDrive/Celeba/train_HR/000121.png')
sr = cv2.imread('/content/Non-Local-Sparse-Attention/experiment/test/results-Celeba/000121_x2_SR.png')

# %%
import cv2

# %%
# %cd /content/
# !unzip /content/drive/MyDrive/Test.zip
# Out:
# /content
# Archive:  /content/drive/MyDrive/Test.zip
#    creating: Test/
#   inflating: __MACOSX/._Test
#   inflating: Test/.DS_Store
#   inflating: __MACOSX/Test/._.DS_Store
#    creating: Test/test_HR/
#    creating: Test/tesr_LR/
#   inflating: Test/test_HR/.DS_Store
#   inflating: __MACOSX/Test/test_HR/._.DS_Store
#   inflating: Test/test_HR/cartoon.png
#   inflating: __MACOSX/Test/test_HR/._cartoon.png
#   inflating: Test/test_HR/baboon.png
#   inflating: __MACOSX/Test/test_HR/._baboon.png
#   inflating: Test/tesr_LR/.DS_Store
#   inflating: __MACOSX/Test/tesr_LR/._.DS_Store
#    creating: Test/tesr_LR/X2/
#   inflating: Test/tesr_LR/X2/cartoonx2.png
#   inflating: __MACOSX/Test/tesr_LR/X2/._cartoonx2.png
#   inflating: Test/tesr_LR/X2/.DS_Store
#   inflating: __MACOSX/Test/tesr_LR/X2/._.DS_Store
#   inflating: Test/tesr_LR/X2/baboonx2.png
#   inflating: __MACOSX/Test/tesr_LR/X2/._baboonx2.png

# %%
# %cd /content/Non-Local-Sparse-Attention/src/
# !python main.py --model NLSN --n_feats 256 --n_resblocks 32 --res_scale 0.1 --data_test Demo --scale 2 --pre_train /content/drive/MyDrive/nlsn_best.pt --test_only --save_results
# Out:
# /content/Non-Local-Sparse-Attention/src
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 18 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Loading model from /content/drive/MyDrive/nlsn_best.pt
# Total params: 41.80M
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 2/2 [00:17<00:00,  8.71s/it]
# [Demo x2]	PSNR: 0.000 (Best: 0.000 @epoch 1)
# Forward: 17.76s
#
# Saving...
# Total: 17.87s

# %%
# !python main.py --dir_data /content/drive/MyDrive/ --model NLSN  --chunk_size 144 --data_test Set5+Set14+B100+Urban100 --n_hashes 4 --chop --save_results --rgb_range 1 --data_range 801-900 --scale 2 --n_feats 256 --n_resblocks 32 --res_scale 0.1  --pre_train  /content/drive/MyDrive/nlsn_best.pt --test_only
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 18 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Making model...
# Loading model from /content/drive/MyDrive/nlsn_best.pt
# Total params: 41.80M
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 5/5 [00:19<00:00,  3.94s/it]
# [Set5 x2]	PSNR: 29.792 (Best: 29.792 @epoch 1)
# 100%|███████████████████████████████████████████| 14/14 [00:22<00:00,  1.62s/it]
# [Set14 x2]	PSNR: 27.847 (Best: 27.847 @epoch 1)
# 100%|█████████████████████████████████████████| 100/100 [01:50<00:00,  1.10s/it]
# [B100 x2]	PSNR: 27.249 (Best: 27.249 @epoch 1)
# ...
